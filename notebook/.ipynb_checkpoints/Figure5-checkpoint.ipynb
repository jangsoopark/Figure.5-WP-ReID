# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/5c/98/211647fc6aa89355c11b028f37ceae95d7e1bbb99ac363cbf4c4297ef4d7/matplotlib-3.8.2-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading matplotlib-3.8.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8a/b8/258adec810e0c4c28292ad1af5736809d393587bd88e79635343fcdc78d0/contourpy-1.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading contourpy-1.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/2b/ff/8c9b05fd2bbdfe6fee7c0e8a3e8981b4454404dca3ef58fc98a6673a6cf8/fonttools-4.46.0-cp39-cp39-macosx_10_9_universal2.whl.metadata
#   Downloading fonttools-4.46.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 4.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/89/a8/3b7e14121bea4438b87630557645bb7648b17b54acaa39b93f4bf7f8d33e/kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/venv/lib/python3.9/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/venv/lib/python3.9/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/91/67/9bf0b3c0f43d5e1aa6795318feefad2ec5e5a10b51454b047dc608619fbb/Pillow-10.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading Pillow-10.1.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Obtaining dependency information for importlib-resources>=3.2.0 from https://files.pythonhosted.org/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 7.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading contourpy-1.2.0-cp39-cp39-macosx_11_0_arm64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 8.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.46.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 6.6 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp39-cp39-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.9 MB/s eta 0:00:000:00:010:00:01:01m
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.46.0 importlib-resources-6.1.1 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.1.0 pyparsing-3.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from matplotlib import pyplot as plt
from rcpm import dataset
from rcpm import utils
from rcpm import eval

from pathlib import Path

import os

# %%
raw_data_folder = Path('/data')
cropped_image_dir = raw_data_folder / 'cropped_data'
split_file_dir = utils.file_abs_path(os.getcwd()) / '_test/files/wp_reid_info.json'

# %%
wp_reid_dataset = dataset.DataBank(
    minframes=3,
    raw_data_folder=raw_data_folder,
    cropped_image_dir=cropped_image_dir,
    split_file_dir=split_file_dir
)
# Out:
# Load data <--- /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/_test/files/wp_reid_info.json
# WPReID dataset
# Gallery ID diff Probe ID: []
#
# +--------+--------+-------+---------+
# |  Raw   |  Test  | Probe | Gallery |
# +--------+--------+-------+---------+
# |  #ID   |   79   |   79  |    79   |
# | #Track |  868   |  239  |   868   |
# | #Image | 106578 | 33345 |  106578 |
# |  #Cam  |   6    |   6   |    6    |
# | MaxLen |  1165  |  1165 |   1165  |
# | MinLen |   3    |   3   |    3    |
# | AvgLen |  122   |  139  |   122   |
# +--------+--------+-------+---------+
# After drop videos less than: test  3 frames, check cam number
# No related gallery track with different camera id. Drop probe [   33     3 96929 97207   278]
# No related gallery track with different camera id. Drop probe [   34     3 97207 97258    51]
# No related gallery track with different camera id. Drop probe [   36     3 97342 97522   180]
# No related gallery track with different camera id. Drop probe [   37     3 97522 97811   289]
# No related gallery track with different camera id. Drop probe [   38     3 97811 98229   418]
# No related gallery track with different camera id. Drop probe [   39     4 98229 98327    98]
# No related gallery track with different camera id. Drop probe [   40     4 98327 98443   116]
# No related gallery track with different camera id. Drop probe [   41     4 98584 98605    21]
# No related gallery track with different camera id. Drop probe [   42     4 98749 98865   116]
# No related gallery track with different camera id. Drop probe [   43     4 98880 99012   132]
# No related gallery track with different camera id. Drop probe [   45     4 99053 99185   132]
# No related gallery track with different camera id. Drop probe [   46     4 99185 99217    32]
# No related gallery track with different camera id. Drop probe [   49     4 99425 99442    17]
# No related gallery track with different camera id. Drop probe [   50     4 99532 99598    66]
# No related gallery track with different camera id. Drop probe [   52     4 99642 99774   132]
# No related gallery track with different camera id. Drop probe [   53     4 99882 99978    96]
# No related gallery track with different camera id. Drop probe [    57      4 100822 100852     30]
# No related gallery track with different camera id. Drop probe [    58      4 102852 102952    100]
# No related gallery track with different camera id. Drop probe [    59      4 103129 103260    131]
# No related gallery track with different camera id. Drop probe [    60      4 103260 103274     14]
# No related gallery track with different camera id. Drop probe [    61      4 103426 103456     30]
# No related gallery track with different camera id. Drop probe [    62      4 103456 103472     16]
# No related gallery track with different camera id. Drop probe [    63      4 103472 103496     24]
# No related gallery track with different camera id. Drop probe [    64      4 103496 103520     24]
# No related gallery track with different camera id. Drop probe [    65      4 103556 103594     38]
# No related gallery track with different camera id. Drop probe [    66      4 104240 104412    172]
# No related gallery track with different camera id. Drop probe [    67      4 104591 104632     41]
# No related gallery track with different camera id. Drop probe [    68      4 104632 105199    567]
# No related gallery track with different camera id. Drop probe [    69      4 105389 105419     30]
# No related gallery track with different camera id. Drop probe [    70      4 105419 105522    103]
# No related gallery track with different camera id. Drop probe [    71      4 105534 105568     34]
# No related gallery track with different camera id. Drop probe [    72      4 105568 105673    105]
# No related gallery track with different camera id. Drop probe [    73      4 105804 105858     54]
# No related gallery track with different camera id. Drop probe [    74      4 105875 105887     12]
# No related gallery track with different camera id. Drop probe [    75      5 106002 106149    147]
# No related gallery track with different camera id. Drop probe [    76      5 106221 106245     24]
# No related gallery track with different camera id. Drop probe [    77      5 106365 106446     81]
# No related gallery track with different camera id. Drop probe [    78      5 106537 106578     41]
# Gallery ID diff Probe ID: [33 34 36 37 38 39 40 41 42 43 45 46 49 50 52 53 57 58 59 60 61 62 63 64
#  65 66 67 68 69 70 71 72 73 74 75 76 77 78]
#
# +------------+--------+-------+---------+
# | After Drop |  Test  | Probe | Gallery |
# +------------+--------+-------+---------+
# |    #ID     |   79   |   41  |    79   |
# |   #Track   |  868   |  201  |   868   |
# |   #Image   | 106578 | 29353 |  106578 |
# |    #Cam    |   6    |   6   |    6    |
# |   MaxLen   |  1165  |  1165 |   1165  |
# |   MinLen   |   3    |   3   |    3    |
# |   AvgLen   |  122   |  146  |   122   |
# +------------+--------+-------+---------+

# %%
files_dir = utils.file_abs_path(os.getcwd()) / '_test/files'

mmt_duke_dist_file = files_dir / 'mmt_duke_g2g_distmat.json'

# %%
import copy
from rcpm import update_module 
from rcpm import video_reid_performance
from rcpm import eval_tools
# import get_vision_record_dist, visual_affinity_update, trajectory_distance_update, norm_data

class AblationRecurrentContextPropagationModule(eval.RecurrentContextPropagationModule):

    def rcpm(self, gt_dist_new, iteration=1):
        distMat_new = update_module.visual_affinity_update(
            self.raw_distMat, 
            gt_dist=gt_dist_new.copy(), 
            T=self.delta, 
            alpha=self.alpha
        )
        cmc_reid, mAP_reid = video_reid_performance.compute_video_cmc_map(
            distMat_new[self.query_index][:, self.gallery_index], 
            self.query_id, self.gallery_id,
            self.query_cam_id, 
            self.gallery_cam_id
        )
        gt_dist_new = update_module.trajectory_distance_update(
            distMat_new, 
            self.raw_gt_dist.copy(), 
            k=self.k
        )
        cmc_SM = eval_tools.get_signal_match_cmc(
            gt_dist_new[self.query_index].copy(), 
            self.gt_dist_is_inf[self.query_index].copy(),
            self.query_id.copy(), 
            self.traj_id.copy()
        )
        
        return gt_dist_new, cmc_reid, mAP_reid, cmc_SM
        
    def __call__(self, *args, **kwargs):
        print('K={}, Delta={}, Iteration={}'.format(self.k, self.delta, self.iters))
        cmc_reid, mAP_reid = video_reid_performance.compute_video_cmc_map(
            self.raw_distMat[self.query_index][:, self.gallery_index], 
            self.query_id, self.gallery_id,
            self.query_cam_id, 
            self.gallery_cam_id
        )
        cmc_SM = eval_tools.get_signal_match_cmc(
            self.raw_gt_dist[self.query_index].copy(), 
            self.gt_dist_is_inf[self.query_index].copy(),
            self.query_id.copy(), 
            self.traj_id.copy()
        )

        # print('Iteration {}: ReID rank-1 {:.2f} mAP {:.2f}. Signal Matching rank-1 {:.2f}'.format(
        #     0, cmc_reid[0] * 100, mAP_reid * 100, cmc_SM[0] * 100))
        
        last_gt_dist = self.raw_gt_dist
        history = {
            'cmc_reid': [],
            'mAP_reid': [],
            'cmc_SM': []
        }
        for i in range(self.iters):
            last_gt_dist, cmc_reid, mAP_reid, cmc_SM = self.rcpm(last_gt_dist, iteration=i+1)
            print('Iteration {}: ReID rank-1 {:.2f} mAP {:.2f}. Signal Matching rank-1 {:.2f}'.format(
                i + 1, cmc_reid[0] * 100, mAP_reid * 100, cmc_SM[0] * 100))
            history['cmc_reid'].append(cmc_reid[0] * 100)
            history['mAP_reid'].append(mAP_reid * 100)
            history['cmc_SM'].append(cmc_SM[0] * 100)

        return history


def ablation_update_with_gps(distMat, all_info, query_index, gallery_index, bndbox_gps, trajectory, k=9, delta=74, iters=5):
    '''
    :param distMat: (g, g), the distance between gallery tracklet with gallery tracklet
    :param all_info: (num, 5), num is the total number of gallery tracklet, each row [p_id, cam_id, idx, idx+frame_num, frame_num]
    :param query_index: the query index for query tracklet in gallery tracklet
    :param gallery_index: the gallery index for query tracklet in gallery tracklet
    :param bndbox_gps: (image_num, 3), each raw: [time_id, gps_j, gps_w]
    :param trajectory: dict, the key is the corresponding person id. trajectory[p_id] : (n, 3), each row [timestamp, gps_j, gps_w]
    :return:
    '''
    gallery_info = all_info[gallery_index]
    gt_gps_dist, traj_id = eval.get_vision_record_dist(gallery_info.copy(), bndbox_gps.copy(), copy.deepcopy(trajectory))
    rcpm = AblationRecurrentContextPropagationModule(k=k, delta=delta, iters=iters, distMat=distMat, gt_dist=gt_gps_dist, traj_id=traj_id)
    rcpm.init_dataset_info(all_info=all_info, query_index=query_index, gallery_index=gallery_index)
    
    return rcpm()

# %% [markdown]
# ## Figure 5 (c) without RCPM$^*$

# %%
k = 8
sigma = 74
max_iters = 8

distmat = utils.DataPacker.load(mmt_duke_dist_file)['g2g_distmat']
history_iters = ablation_update_with_gps(
    distmat, 
    wp_reid_dataset.test_info, 
    wp_reid_dataset.probe_index, 
    wp_reid_dataset.gallery_index,
    wp_reid_dataset.gps_info, 
    wp_reid_dataset.trajectory_info, 
    k=k,
    delta=sigma,
    iters=max_iters
)

# print(cmc_reid, mAP_reid, cmc_SM)
# Out:
# Load data <--- /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/_test/files/mmt_duke_g2g_distmat.json
# K=8, Delta=74, Iteration=8
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 59.09. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 60.87. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.47. Signal Matching rank-1 84.76
# Iteration 5: ReID rank-1 77.11 mAP 61.02. Signal Matching rank-1 86.59
# Iteration 6: ReID rank-1 78.11 mAP 61.41. Signal Matching rank-1 86.59
# Iteration 7: ReID rank-1 77.11 mAP 61.30. Signal Matching rank-1 86.59
# Iteration 8: ReID rank-1 76.62 mAP 61.40. Signal Matching rank-1 86.59

# %%
plt.plot(list(range(8)), history_iters['cmc_SM'], '-p', color='blue', label='RCPM SM Rank-1')
plt.plot(list(range(8)), history_iters['cmc_reid'], '--p', color='blue', label='RCPM ReID Rank-1')
plt.plot(list(range(8)), history_iters['mAP_reid'], '-.p', color='blue', label='RCPM ReID mAP')

plt.legend()

# %% [markdown]
# ## Figure 5 (a)

# %%
# k = 8
sigma = 74
max_iters = 4

distmat = utils.DataPacker.load(mmt_duke_dist_file)['g2g_distmat']

history_k = {
    'cmc_reid': [],
    'mAP_reid': [],
    'cmc_SM': []
}
for k in range(1, 20):
    
    history = ablation_update_with_gps(
        distmat, 
        wp_reid_dataset.test_info, 
        wp_reid_dataset.probe_index, 
        wp_reid_dataset.gallery_index,
        wp_reid_dataset.gps_info, 
        wp_reid_dataset.trajectory_info, 
        k=k,
        delta=sigma,
        iters=max_iters
    )

    history_k['cmc_reid'].append(history['cmc_reid'][-1])
    history_k['mAP_reid'].append(history['mAP_reid'][-1])
    history_k['cmc_SM'].append(history['cmc_SM'][-1])

# print(cmc_reid, mAP_reid, cmc_SM)
# Out:
# Load data <--- /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/_test/files/mmt_duke_g2g_distmat.json
# K=1, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 53.66
# Iteration 2: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 53.66
# Iteration 3: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 53.66
# Iteration 4: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 53.66
# K=2, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 67.07
# Iteration 2: ReID rank-1 74.13 mAP 54.37. Signal Matching rank-1 69.51
# Iteration 3: ReID rank-1 73.63 mAP 54.81. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.63 mAP 54.78. Signal Matching rank-1 70.12
# K=3, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 77.44
# Iteration 2: ReID rank-1 75.12 mAP 58.23. Signal Matching rank-1 78.05
# Iteration 3: ReID rank-1 76.12 mAP 58.21. Signal Matching rank-1 78.05
# Iteration 4: ReID rank-1 76.62 mAP 58.36. Signal Matching rank-1 77.44
# K=4, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 75.12 mAP 58.54. Signal Matching rank-1 78.66
# Iteration 3: ReID rank-1 75.62 mAP 58.93. Signal Matching rank-1 78.05
# Iteration 4: ReID rank-1 75.12 mAP 58.94. Signal Matching rank-1 78.05
# K=5, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 74.63 mAP 59.10. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.62 mAP 60.59. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.12 mAP 60.65. Signal Matching rank-1 84.76
# K=6, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 74.63 mAP 59.34. Signal Matching rank-1 86.59
# Iteration 3: ReID rank-1 76.12 mAP 61.16. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 76.12 mAP 61.22. Signal Matching rank-1 86.59
# K=7, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 75.12 mAP 59.06. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 60.85. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.11 mAP 61.46. Signal Matching rank-1 86.59
# K=8, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 59.09. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 60.87. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.47. Signal Matching rank-1 84.76
# K=9, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 58.99. Signal Matching rank-1 87.20
# Iteration 3: ReID rank-1 76.62 mAP 61.20. Signal Matching rank-1 88.41
# Iteration 4: ReID rank-1 77.61 mAP 61.65. Signal Matching rank-1 88.41
# K=10, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 76.12 mAP 58.53. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 75.62 mAP 60.05. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 76.12 mAP 60.47. Signal Matching rank-1 87.20
# K=11, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 74.13 mAP 57.62. Signal Matching rank-1 82.93
# Iteration 3: ReID rank-1 76.12 mAP 59.83. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 76.12 mAP 59.40. Signal Matching rank-1 84.76
# K=12, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 75.62 mAP 57.13. Signal Matching rank-1 82.93
# Iteration 3: ReID rank-1 75.12 mAP 58.86. Signal Matching rank-1 81.71
# Iteration 4: ReID rank-1 76.62 mAP 58.99. Signal Matching rank-1 82.32
# K=13, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 78.66
# Iteration 2: ReID rank-1 74.63 mAP 56.81. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 75.12 mAP 58.43. Signal Matching rank-1 80.49
# Iteration 4: ReID rank-1 74.13 mAP 57.46. Signal Matching rank-1 81.10
# K=14, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 74.63 mAP 56.67. Signal Matching rank-1 79.88
# Iteration 3: ReID rank-1 74.13 mAP 57.75. Signal Matching rank-1 80.49
# Iteration 4: ReID rank-1 73.13 mAP 57.02. Signal Matching rank-1 79.88
# K=15, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 77.44
# Iteration 2: ReID rank-1 74.13 mAP 56.23. Signal Matching rank-1 78.66
# Iteration 3: ReID rank-1 74.13 mAP 57.34. Signal Matching rank-1 79.27
# Iteration 4: ReID rank-1 72.64 mAP 56.18. Signal Matching rank-1 79.27
# K=16, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 77.44
# Iteration 2: ReID rank-1 74.63 mAP 55.76. Signal Matching rank-1 77.44
# Iteration 3: ReID rank-1 73.63 mAP 56.27. Signal Matching rank-1 78.66
# Iteration 4: ReID rank-1 72.64 mAP 55.75. Signal Matching rank-1 78.05
# K=17, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 76.83
# Iteration 2: ReID rank-1 74.63 mAP 55.18. Signal Matching rank-1 76.22
# Iteration 3: ReID rank-1 74.13 mAP 56.15. Signal Matching rank-1 76.22
# Iteration 4: ReID rank-1 72.64 mAP 55.23. Signal Matching rank-1 73.17
# K=18, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 75.61
# Iteration 2: ReID rank-1 74.63 mAP 54.55. Signal Matching rank-1 73.78
# Iteration 3: ReID rank-1 73.63 mAP 54.94. Signal Matching rank-1 73.78
# Iteration 4: ReID rank-1 73.13 mAP 53.90. Signal Matching rank-1 70.73
# K=19, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 75.00
# Iteration 2: ReID rank-1 74.13 mAP 53.88. Signal Matching rank-1 73.17
# Iteration 3: ReID rank-1 74.13 mAP 54.79. Signal Matching rank-1 71.95
# Iteration 4: ReID rank-1 72.14 mAP 53.57. Signal Matching rank-1 70.12

# %%
len(history_k['cmc_SM']), len(list(range(max_iters - 1)))
# Out:
# (19, 3)

# %%
plt.plot(list(range(19)), history_k['cmc_SM'], '-', color='blue', label='RCPM SM Rank-1')
plt.plot(list(range(19)), history_k['cmc_reid'], '--', color='blue', label='RCPM ReID Rank-1')
plt.plot(list(range(19)), history_k['mAP_reid'], '-.', color='blue', label='RCPM ReID mAP')

plt.legend()

# %% [markdown]
# ## Figure 5 (b)

# %%
k = 8
# sigma = 74
max_iters = 4

distmat = utils.DataPacker.load(mmt_duke_dist_file)['g2g_distmat']

history_sigma = {
    'cmc_reid': [],
    'mAP_reid': [],
    'cmc_SM': []
}
for sigma in range(1, 141):
    
    history = ablation_update_with_gps(
        distmat, 
        wp_reid_dataset.test_info, 
        wp_reid_dataset.probe_index, 
        wp_reid_dataset.gallery_index,
        wp_reid_dataset.gps_info, 
        wp_reid_dataset.trajectory_info, 
        k=k,
        delta=sigma,
        iters=max_iters
    )

    history_sigma['cmc_reid'].append(history['cmc_reid'][-1])
    history_sigma['mAP_reid'].append(history['mAP_reid'][-1])
    history_sigma['cmc_SM'].append(history['cmc_SM'][-1])

# print(cmc_reid, mAP_reid, cmc_SM)
# Out:
# Load data <--- /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/_test/files/mmt_duke_g2g_distmat.json
# K=8, Delta=1, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=2, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=3, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 37.78. Signal Matching rank-1 70.12
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=4, Iteration=4
# Iteration 1: ReID rank-1 72.64 mAP 37.56. Signal Matching rank-1 69.51
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=5, Iteration=4
# Iteration 1: ReID rank-1 72.14 mAP 36.23. Signal Matching rank-1 70.12
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=6, Iteration=4
# Iteration 1: ReID rank-1 69.65 mAP 33.90. Signal Matching rank-1 67.68
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=7, Iteration=4
# Iteration 1: ReID rank-1 68.16 mAP 31.11. Signal Matching rank-1 65.85
# Iteration 2: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 73.13 mAP 36.79. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 73.13 mAP 37.81. Signal Matching rank-1 70.12
# K=8, Delta=8, Iteration=4
# Iteration 1: ReID rank-1 64.68 mAP 28.22. Signal Matching rank-1 56.10
# Iteration 2: ReID rank-1 73.13 mAP 37.62. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 72.14 mAP 34.29. Signal Matching rank-1 68.90
# Iteration 4: ReID rank-1 73.13 mAP 37.82. Signal Matching rank-1 70.12
# K=8, Delta=9, Iteration=4
# Iteration 1: ReID rank-1 56.22 mAP 25.47. Signal Matching rank-1 52.44
# Iteration 2: ReID rank-1 73.13 mAP 37.52. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 71.64 mAP 32.14. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 73.13 mAP 37.56. Signal Matching rank-1 70.12
# K=8, Delta=10, Iteration=4
# Iteration 1: ReID rank-1 52.24 mAP 23.60. Signal Matching rank-1 45.73
# Iteration 2: ReID rank-1 73.13 mAP 37.16. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 70.65 mAP 31.14. Signal Matching rank-1 65.85
# Iteration 4: ReID rank-1 73.13 mAP 37.75. Signal Matching rank-1 70.12
# K=8, Delta=11, Iteration=4
# Iteration 1: ReID rank-1 51.24 mAP 22.92. Signal Matching rank-1 43.90
# Iteration 2: ReID rank-1 73.13 mAP 36.90. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 69.65 mAP 30.43. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 73.13 mAP 37.42. Signal Matching rank-1 70.12
# K=8, Delta=12, Iteration=4
# Iteration 1: ReID rank-1 49.25 mAP 23.01. Signal Matching rank-1 43.90
# Iteration 2: ReID rank-1 73.13 mAP 37.11. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 68.66 mAP 28.98. Signal Matching rank-1 62.20
# Iteration 4: ReID rank-1 73.13 mAP 37.26. Signal Matching rank-1 70.12
# K=8, Delta=13, Iteration=4
# Iteration 1: ReID rank-1 49.25 mAP 24.03. Signal Matching rank-1 42.07
# Iteration 2: ReID rank-1 73.13 mAP 36.91. Signal Matching rank-1 70.12
# Iteration 3: ReID rank-1 68.16 mAP 29.36. Signal Matching rank-1 58.54
# Iteration 4: ReID rank-1 73.13 mAP 37.13. Signal Matching rank-1 70.12
# K=8, Delta=14, Iteration=4
# Iteration 1: ReID rank-1 46.77 mAP 24.44. Signal Matching rank-1 43.90
# Iteration 2: ReID rank-1 73.13 mAP 36.48. Signal Matching rank-1 69.51
# Iteration 3: ReID rank-1 68.16 mAP 29.66. Signal Matching rank-1 59.76
# Iteration 4: ReID rank-1 72.64 mAP 36.68. Signal Matching rank-1 69.51
# K=8, Delta=15, Iteration=4
# Iteration 1: ReID rank-1 47.26 mAP 26.21. Signal Matching rank-1 48.17
# Iteration 2: ReID rank-1 73.13 mAP 35.98. Signal Matching rank-1 69.51
# Iteration 3: ReID rank-1 67.16 mAP 29.96. Signal Matching rank-1 60.98
# Iteration 4: ReID rank-1 72.64 mAP 36.06. Signal Matching rank-1 67.68
# K=8, Delta=16, Iteration=4
# Iteration 1: ReID rank-1 48.26 mAP 28.14. Signal Matching rank-1 50.00
# Iteration 2: ReID rank-1 72.14 mAP 35.60. Signal Matching rank-1 67.07
# Iteration 3: ReID rank-1 69.15 mAP 30.37. Signal Matching rank-1 61.59
# Iteration 4: ReID rank-1 73.13 mAP 36.03. Signal Matching rank-1 68.90
# K=8, Delta=17, Iteration=4
# Iteration 1: ReID rank-1 50.25 mAP 30.16. Signal Matching rank-1 52.44
# Iteration 2: ReID rank-1 71.64 mAP 34.89. Signal Matching rank-1 68.29
# Iteration 3: ReID rank-1 70.15 mAP 30.99. Signal Matching rank-1 63.41
# Iteration 4: ReID rank-1 72.14 mAP 35.06. Signal Matching rank-1 67.68
# K=8, Delta=18, Iteration=4
# Iteration 1: ReID rank-1 51.24 mAP 32.06. Signal Matching rank-1 53.05
# Iteration 2: ReID rank-1 71.14 mAP 33.54. Signal Matching rank-1 67.07
# Iteration 3: ReID rank-1 68.66 mAP 31.74. Signal Matching rank-1 64.02
# Iteration 4: ReID rank-1 72.64 mAP 34.05. Signal Matching rank-1 68.90
# K=8, Delta=19, Iteration=4
# Iteration 1: ReID rank-1 54.23 mAP 33.86. Signal Matching rank-1 55.49
# Iteration 2: ReID rank-1 70.15 mAP 32.48. Signal Matching rank-1 65.85
# Iteration 3: ReID rank-1 69.65 mAP 31.86. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 71.64 mAP 34.01. Signal Matching rank-1 65.85
# K=8, Delta=20, Iteration=4
# Iteration 1: ReID rank-1 54.73 mAP 35.52. Signal Matching rank-1 56.71
# Iteration 2: ReID rank-1 70.15 mAP 33.00. Signal Matching rank-1 67.07
# Iteration 3: ReID rank-1 69.15 mAP 32.56. Signal Matching rank-1 66.46
# Iteration 4: ReID rank-1 70.65 mAP 32.34. Signal Matching rank-1 65.85
# K=8, Delta=21, Iteration=4
# Iteration 1: ReID rank-1 56.22 mAP 37.04. Signal Matching rank-1 59.76
# Iteration 2: ReID rank-1 68.66 mAP 33.14. Signal Matching rank-1 66.46
# Iteration 3: ReID rank-1 70.15 mAP 32.90. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 71.14 mAP 32.76. Signal Matching rank-1 65.85
# K=8, Delta=22, Iteration=4
# Iteration 1: ReID rank-1 58.21 mAP 38.80. Signal Matching rank-1 64.63
# Iteration 2: ReID rank-1 68.16 mAP 34.21. Signal Matching rank-1 64.02
# Iteration 3: ReID rank-1 70.15 mAP 32.45. Signal Matching rank-1 65.85
# Iteration 4: ReID rank-1 69.65 mAP 32.58. Signal Matching rank-1 64.02
# K=8, Delta=23, Iteration=4
# Iteration 1: ReID rank-1 61.19 mAP 40.32. Signal Matching rank-1 65.85
# Iteration 2: ReID rank-1 67.66 mAP 34.59. Signal Matching rank-1 65.24
# Iteration 3: ReID rank-1 68.66 mAP 32.29. Signal Matching rank-1 63.41
# Iteration 4: ReID rank-1 69.15 mAP 31.56. Signal Matching rank-1 63.41
# K=8, Delta=24, Iteration=4
# Iteration 1: ReID rank-1 64.18 mAP 41.88. Signal Matching rank-1 70.12
# Iteration 2: ReID rank-1 64.18 mAP 34.56. Signal Matching rank-1 64.02
# Iteration 3: ReID rank-1 68.16 mAP 33.04. Signal Matching rank-1 64.63
# Iteration 4: ReID rank-1 68.16 mAP 31.89. Signal Matching rank-1 64.02
# K=8, Delta=25, Iteration=4
# Iteration 1: ReID rank-1 64.18 mAP 43.01. Signal Matching rank-1 71.34
# Iteration 2: ReID rank-1 64.18 mAP 34.88. Signal Matching rank-1 60.98
# Iteration 3: ReID rank-1 68.66 mAP 33.59. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 67.66 mAP 31.14. Signal Matching rank-1 60.37
# K=8, Delta=26, Iteration=4
# Iteration 1: ReID rank-1 65.17 mAP 44.21. Signal Matching rank-1 71.34
# Iteration 2: ReID rank-1 64.68 mAP 35.50. Signal Matching rank-1 60.37
# Iteration 3: ReID rank-1 66.67 mAP 33.97. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 66.17 mAP 32.79. Signal Matching rank-1 60.37
# K=8, Delta=27, Iteration=4
# Iteration 1: ReID rank-1 67.16 mAP 45.33. Signal Matching rank-1 71.95
# Iteration 2: ReID rank-1 65.67 mAP 36.44. Signal Matching rank-1 59.76
# Iteration 3: ReID rank-1 67.16 mAP 34.91. Signal Matching rank-1 66.46
# Iteration 4: ReID rank-1 67.66 mAP 33.31. Signal Matching rank-1 61.59
# K=8, Delta=28, Iteration=4
# Iteration 1: ReID rank-1 66.67 mAP 46.31. Signal Matching rank-1 73.78
# Iteration 2: ReID rank-1 66.67 mAP 37.51. Signal Matching rank-1 60.37
# Iteration 3: ReID rank-1 68.16 mAP 35.96. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 68.66 mAP 34.22. Signal Matching rank-1 61.59
# K=8, Delta=29, Iteration=4
# Iteration 1: ReID rank-1 67.16 mAP 47.15. Signal Matching rank-1 73.78
# Iteration 2: ReID rank-1 64.18 mAP 37.06. Signal Matching rank-1 58.54
# Iteration 3: ReID rank-1 68.66 mAP 37.40. Signal Matching rank-1 66.46
# Iteration 4: ReID rank-1 67.16 mAP 34.58. Signal Matching rank-1 60.98
# K=8, Delta=30, Iteration=4
# Iteration 1: ReID rank-1 68.16 mAP 47.71. Signal Matching rank-1 76.83
# Iteration 2: ReID rank-1 63.18 mAP 38.63. Signal Matching rank-1 60.37
# Iteration 3: ReID rank-1 66.17 mAP 36.45. Signal Matching rank-1 65.24
# Iteration 4: ReID rank-1 66.17 mAP 33.96. Signal Matching rank-1 64.02
# K=8, Delta=31, Iteration=4
# Iteration 1: ReID rank-1 68.66 mAP 48.39. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 62.19 mAP 40.15. Signal Matching rank-1 63.41
# Iteration 3: ReID rank-1 65.67 mAP 36.40. Signal Matching rank-1 62.80
# Iteration 4: ReID rank-1 66.67 mAP 34.75. Signal Matching rank-1 63.41
# K=8, Delta=32, Iteration=4
# Iteration 1: ReID rank-1 69.65 mAP 49.09. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 63.68 mAP 41.12. Signal Matching rank-1 64.02
# Iteration 3: ReID rank-1 66.17 mAP 37.71. Signal Matching rank-1 64.02
# Iteration 4: ReID rank-1 65.67 mAP 35.46. Signal Matching rank-1 62.80
# K=8, Delta=33, Iteration=4
# Iteration 1: ReID rank-1 70.15 mAP 49.71. Signal Matching rank-1 79.88
# Iteration 2: ReID rank-1 61.19 mAP 42.26. Signal Matching rank-1 66.46
# Iteration 3: ReID rank-1 66.67 mAP 37.89. Signal Matching rank-1 64.63
# Iteration 4: ReID rank-1 67.66 mAP 36.95. Signal Matching rank-1 64.02
# K=8, Delta=34, Iteration=4
# Iteration 1: ReID rank-1 70.65 mAP 50.03. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 63.18 mAP 43.48. Signal Matching rank-1 67.07
# Iteration 3: ReID rank-1 66.67 mAP 38.53. Signal Matching rank-1 64.02
# Iteration 4: ReID rank-1 68.66 mAP 37.36. Signal Matching rank-1 64.02
# K=8, Delta=35, Iteration=4
# Iteration 1: ReID rank-1 71.14 mAP 50.54. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 62.69 mAP 44.86. Signal Matching rank-1 66.46
# Iteration 3: ReID rank-1 65.67 mAP 39.73. Signal Matching rank-1 64.02
# Iteration 4: ReID rank-1 66.67 mAP 37.10. Signal Matching rank-1 60.37
# K=8, Delta=36, Iteration=4
# Iteration 1: ReID rank-1 71.14 mAP 50.24. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 63.68 mAP 45.94. Signal Matching rank-1 67.07
# Iteration 3: ReID rank-1 66.67 mAP 40.50. Signal Matching rank-1 66.46
# Iteration 4: ReID rank-1 64.68 mAP 38.24. Signal Matching rank-1 61.59
# K=8, Delta=37, Iteration=4
# Iteration 1: ReID rank-1 71.64 mAP 50.59. Signal Matching rank-1 78.66
# Iteration 2: ReID rank-1 63.18 mAP 47.19. Signal Matching rank-1 69.51
# Iteration 3: ReID rank-1 66.67 mAP 42.05. Signal Matching rank-1 70.12
# Iteration 4: ReID rank-1 66.17 mAP 38.80. Signal Matching rank-1 64.02
# K=8, Delta=38, Iteration=4
# Iteration 1: ReID rank-1 71.64 mAP 50.85. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 66.17 mAP 48.44. Signal Matching rank-1 73.17
# Iteration 3: ReID rank-1 66.17 mAP 43.62. Signal Matching rank-1 70.73
# Iteration 4: ReID rank-1 64.68 mAP 39.01. Signal Matching rank-1 61.59
# K=8, Delta=39, Iteration=4
# Iteration 1: ReID rank-1 72.14 mAP 51.06. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 65.67 mAP 49.28. Signal Matching rank-1 71.95
# Iteration 3: ReID rank-1 69.15 mAP 44.65. Signal Matching rank-1 70.73
# Iteration 4: ReID rank-1 65.67 mAP 40.58. Signal Matching rank-1 65.85
# K=8, Delta=40, Iteration=4
# Iteration 1: ReID rank-1 72.64 mAP 51.23. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 66.67 mAP 50.09. Signal Matching rank-1 71.34
# Iteration 3: ReID rank-1 70.15 mAP 45.96. Signal Matching rank-1 70.73
# Iteration 4: ReID rank-1 65.67 mAP 41.57. Signal Matching rank-1 67.68
# K=8, Delta=41, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.43. Signal Matching rank-1 78.66
# Iteration 2: ReID rank-1 68.16 mAP 51.46. Signal Matching rank-1 71.95
# Iteration 3: ReID rank-1 68.16 mAP 46.78. Signal Matching rank-1 69.51
# Iteration 4: ReID rank-1 66.17 mAP 42.97. Signal Matching rank-1 65.24
# K=8, Delta=42, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.45. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 67.66 mAP 52.04. Signal Matching rank-1 73.17
# Iteration 3: ReID rank-1 69.65 mAP 47.72. Signal Matching rank-1 70.73
# Iteration 4: ReID rank-1 65.67 mAP 43.85. Signal Matching rank-1 68.90
# K=8, Delta=43, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.57. Signal Matching rank-1 77.44
# Iteration 2: ReID rank-1 69.65 mAP 53.31. Signal Matching rank-1 75.00
# Iteration 3: ReID rank-1 70.15 mAP 49.32. Signal Matching rank-1 73.78
# Iteration 4: ReID rank-1 66.67 mAP 44.70. Signal Matching rank-1 70.73
# K=8, Delta=44, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 51.53. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 69.65 mAP 53.90. Signal Matching rank-1 75.61
# Iteration 3: ReID rank-1 68.66 mAP 50.18. Signal Matching rank-1 73.78
# Iteration 4: ReID rank-1 68.66 mAP 47.97. Signal Matching rank-1 71.34
# K=8, Delta=45, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 51.60. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 70.15 mAP 55.13. Signal Matching rank-1 78.05
# Iteration 3: ReID rank-1 70.65 mAP 52.71. Signal Matching rank-1 74.39
# Iteration 4: ReID rank-1 68.16 mAP 49.71. Signal Matching rank-1 70.12
# K=8, Delta=46, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.61. Signal Matching rank-1 78.05
# Iteration 2: ReID rank-1 71.14 mAP 55.66. Signal Matching rank-1 79.27
# Iteration 3: ReID rank-1 69.65 mAP 53.87. Signal Matching rank-1 76.22
# Iteration 4: ReID rank-1 70.15 mAP 51.03. Signal Matching rank-1 75.00
# K=8, Delta=47, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 52.03. Signal Matching rank-1 79.27
# Iteration 2: ReID rank-1 72.64 mAP 56.42. Signal Matching rank-1 80.49
# Iteration 3: ReID rank-1 71.14 mAP 55.88. Signal Matching rank-1 79.88
# Iteration 4: ReID rank-1 69.15 mAP 53.54. Signal Matching rank-1 74.39
# K=8, Delta=48, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.53. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 72.14 mAP 56.35. Signal Matching rank-1 82.93
# Iteration 3: ReID rank-1 71.64 mAP 57.17. Signal Matching rank-1 80.49
# Iteration 4: ReID rank-1 68.66 mAP 54.10. Signal Matching rank-1 75.61
# K=8, Delta=49, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 51.52. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 72.64 mAP 56.87. Signal Matching rank-1 82.93
# Iteration 3: ReID rank-1 72.64 mAP 57.74. Signal Matching rank-1 80.49
# Iteration 4: ReID rank-1 68.66 mAP 55.36. Signal Matching rank-1 75.61
# K=8, Delta=50, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 50.50. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 72.64 mAP 57.22. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 70.65 mAP 58.63. Signal Matching rank-1 81.71
# Iteration 4: ReID rank-1 71.64 mAP 57.26. Signal Matching rank-1 79.27
# K=8, Delta=51, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 50.48. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 72.64 mAP 57.39. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 71.64 mAP 58.73. Signal Matching rank-1 81.71
# Iteration 4: ReID rank-1 70.65 mAP 56.78. Signal Matching rank-1 77.44
# K=8, Delta=52, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 50.44. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 73.13 mAP 57.75. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 72.14 mAP 58.67. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 70.65 mAP 58.39. Signal Matching rank-1 81.10
# K=8, Delta=53, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 50.44. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 73.63 mAP 58.28. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 73.13 mAP 59.61. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 73.13 mAP 59.66. Signal Matching rank-1 81.71
# K=8, Delta=54, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 50.52. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 73.63 mAP 58.81. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 74.13 mAP 60.25. Signal Matching rank-1 83.54
# Iteration 4: ReID rank-1 76.12 mAP 59.60. Signal Matching rank-1 81.10
# K=8, Delta=55, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 50.50. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 74.13 mAP 59.02. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 75.12 mAP 60.85. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 74.63 mAP 60.57. Signal Matching rank-1 82.93
# K=8, Delta=56, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 50.49. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 59.16. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 75.12 mAP 61.62. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 76.12 mAP 60.99. Signal Matching rank-1 82.32
# K=8, Delta=57, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 50.43. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 59.68. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 62.06. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 75.12 mAP 61.21. Signal Matching rank-1 84.15
# K=8, Delta=58, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 50.40. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.12 mAP 60.60. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 78.11 mAP 62.45. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 79.10 mAP 63.01. Signal Matching rank-1 85.98
# K=8, Delta=59, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 50.37. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.12 mAP 60.63. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 78.61 mAP 62.43. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 62.80. Signal Matching rank-1 85.98
# K=8, Delta=60, Iteration=4
# Iteration 1: ReID rank-1 74.63 mAP 50.31. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 59.79. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.61 mAP 62.26. Signal Matching rank-1 87.20
# Iteration 4: ReID rank-1 78.61 mAP 62.69. Signal Matching rank-1 85.98
# K=8, Delta=61, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 49.81. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 59.97. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.11 mAP 61.31. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.11 mAP 61.08. Signal Matching rank-1 84.76
# K=8, Delta=62, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 49.78. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 74.63 mAP 59.74. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 78.61 mAP 61.60. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 76.62 mAP 61.07. Signal Matching rank-1 84.76
# K=8, Delta=63, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.49. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 60.23. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.61 mAP 61.27. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 61.77. Signal Matching rank-1 85.37
# K=8, Delta=64, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.54. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.12 mAP 60.24. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.61 mAP 61.47. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.77. Signal Matching rank-1 84.76
# K=8, Delta=65, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.51. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.12 mAP 60.38. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.61 mAP 61.35. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 61.93. Signal Matching rank-1 84.76
# K=8, Delta=66, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.49. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.62 mAP 60.53. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.11 mAP 61.65. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 62.09. Signal Matching rank-1 85.37
# K=8, Delta=67, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.47. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 77.11 mAP 60.51. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 61.58. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.61 mAP 62.50. Signal Matching rank-1 85.37
# K=8, Delta=68, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.43. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 76.12 mAP 59.64. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 78.61 mAP 62.15. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.61 mAP 62.23. Signal Matching rank-1 85.37
# K=8, Delta=69, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.32. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 59.63. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 78.11 mAP 61.51. Signal Matching rank-1 87.20
# Iteration 4: ReID rank-1 78.11 mAP 62.42. Signal Matching rank-1 85.37
# K=8, Delta=70, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.27. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 59.60. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 78.11 mAP 61.77. Signal Matching rank-1 87.20
# Iteration 4: ReID rank-1 79.10 mAP 62.90. Signal Matching rank-1 86.59
# K=8, Delta=71, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.26. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 75.12 mAP 59.38. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 77.61 mAP 61.44. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 61.87. Signal Matching rank-1 85.98
# K=8, Delta=72, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.18. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 75.12 mAP 59.14. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 77.61 mAP 60.98. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.61 mAP 61.73. Signal Matching rank-1 85.37
# K=8, Delta=73, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 74.63 mAP 59.07. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 77.11 mAP 61.02. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.43. Signal Matching rank-1 85.37
# K=8, Delta=74, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 59.09. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 60.87. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.47. Signal Matching rank-1 84.76
# K=8, Delta=75, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.12. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 59.30. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 61.06. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.55. Signal Matching rank-1 85.37
# K=8, Delta=76, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.48. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.62 mAP 59.15. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 60.59. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 76.62 mAP 60.87. Signal Matching rank-1 85.37
# K=8, Delta=77, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 49.41. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.62 mAP 58.94. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.62 mAP 60.23. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 76.12 mAP 60.47. Signal Matching rank-1 84.76
# K=8, Delta=78, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.27. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 74.63 mAP 58.83. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.62 mAP 60.10. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 76.62 mAP 60.46. Signal Matching rank-1 84.76
# K=8, Delta=79, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.24. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.12 mAP 58.92. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.62 mAP 60.32. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.11 mAP 60.51. Signal Matching rank-1 84.76
# K=8, Delta=80, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.20. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.12 mAP 58.81. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 60.48. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.11 mAP 60.45. Signal Matching rank-1 84.76
# K=8, Delta=81, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.13. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.12 mAP 58.79. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 60.53. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.11 mAP 60.35. Signal Matching rank-1 84.76
# K=8, Delta=82, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.10. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.12 mAP 58.72. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 60.43. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 76.62 mAP 60.08. Signal Matching rank-1 84.76
# K=8, Delta=83, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.06. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.12 mAP 58.62. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 60.22. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 78.11 mAP 60.66. Signal Matching rank-1 85.37
# K=8, Delta=84, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 49.03. Signal Matching rank-1 82.93
# Iteration 2: ReID rank-1 75.62 mAP 58.48. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 59.95. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 78.11 mAP 60.30. Signal Matching rank-1 85.98
# K=8, Delta=85, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.98. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 58.28. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 59.84. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.61 mAP 60.19. Signal Matching rank-1 85.98
# K=8, Delta=86, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.94. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 58.25. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 77.11 mAP 59.39. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 60.02. Signal Matching rank-1 85.98
# K=8, Delta=87, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.89. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 58.13. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 77.11 mAP 59.31. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.11 mAP 59.79. Signal Matching rank-1 85.98
# K=8, Delta=88, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.84. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 58.12. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 59.22. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.61 mAP 59.82. Signal Matching rank-1 85.37
# K=8, Delta=89, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.77. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 57.92. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 76.62 mAP 59.09. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.61 mAP 59.83. Signal Matching rank-1 86.59
# K=8, Delta=90, Iteration=4
# Iteration 1: ReID rank-1 72.64 mAP 48.71. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 57.87. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 76.62 mAP 58.99. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.61 mAP 59.82. Signal Matching rank-1 86.59
# K=8, Delta=91, Iteration=4
# Iteration 1: ReID rank-1 72.64 mAP 48.65. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 58.09. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 76.62 mAP 58.72. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.61 mAP 59.73. Signal Matching rank-1 86.59
# K=8, Delta=92, Iteration=4
# Iteration 1: ReID rank-1 72.64 mAP 48.58. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 57.67. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 58.68. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 59.72. Signal Matching rank-1 87.20
# K=8, Delta=93, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.56. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 57.65. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.61 mAP 58.96. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 59.52. Signal Matching rank-1 86.59
# K=8, Delta=94, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.52. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 57.60. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 76.62 mAP 58.97. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.11 mAP 59.39. Signal Matching rank-1 86.59
# K=8, Delta=95, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.48. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 57.54. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 76.12 mAP 58.98. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 59.62. Signal Matching rank-1 86.59
# K=8, Delta=96, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.47. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.82. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.11 mAP 59.36. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 78.11 mAP 59.85. Signal Matching rank-1 85.98
# K=8, Delta=97, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.41. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.62 mAP 57.91. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.11 mAP 59.21. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.61 mAP 59.68. Signal Matching rank-1 85.37
# K=8, Delta=98, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.38. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.72. Signal Matching rank-1 85.98
# Iteration 3: ReID rank-1 77.11 mAP 59.11. Signal Matching rank-1 85.98
# Iteration 4: ReID rank-1 77.61 mAP 59.57. Signal Matching rank-1 85.37
# K=8, Delta=99, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.33. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.62. Signal Matching rank-1 85.37
# Iteration 3: ReID rank-1 77.11 mAP 58.79. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 59.24. Signal Matching rank-1 84.15
# K=8, Delta=100, Iteration=4
# Iteration 1: ReID rank-1 73.13 mAP 48.30. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.43. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.62 mAP 58.61. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 59.02. Signal Matching rank-1 84.76
# K=8, Delta=101, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 48.42. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.36. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 58.55. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 58.92. Signal Matching rank-1 85.37
# K=8, Delta=102, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 48.36. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.25. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 58.44. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 58.87. Signal Matching rank-1 84.15
# K=8, Delta=103, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 48.31. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 57.17. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 58.28. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 58.65. Signal Matching rank-1 84.15
# K=8, Delta=104, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 48.26. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.62 mAP 57.13. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 58.20. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.61 mAP 58.46. Signal Matching rank-1 84.15
# K=8, Delta=105, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 48.22. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.62 mAP 57.06. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 58.02. Signal Matching rank-1 85.37
# Iteration 4: ReID rank-1 77.61 mAP 58.33. Signal Matching rank-1 84.15
# K=8, Delta=106, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 48.22. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 56.97. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 57.95. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 77.61 mAP 58.23. Signal Matching rank-1 85.37
# K=8, Delta=107, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 48.17. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 56.87. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 57.83. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 77.61 mAP 58.14. Signal Matching rank-1 84.76
# K=8, Delta=108, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 48.11. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 76.12 mAP 56.65. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 57.69. Signal Matching rank-1 83.54
# Iteration 4: ReID rank-1 77.61 mAP 57.96. Signal Matching rank-1 84.15
# K=8, Delta=109, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 48.06. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.56. Signal Matching rank-1 84.76
# Iteration 3: ReID rank-1 76.12 mAP 57.59. Signal Matching rank-1 83.54
# Iteration 4: ReID rank-1 77.61 mAP 57.84. Signal Matching rank-1 84.15
# K=8, Delta=110, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.97. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.38. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.37. Signal Matching rank-1 83.54
# Iteration 4: ReID rank-1 77.11 mAP 57.62. Signal Matching rank-1 84.76
# K=8, Delta=111, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.91. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.36. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.38. Signal Matching rank-1 83.54
# Iteration 4: ReID rank-1 77.11 mAP 57.56. Signal Matching rank-1 84.76
# K=8, Delta=112, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.90. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.26. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.40. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 57.23. Signal Matching rank-1 83.54
# K=8, Delta=113, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.83. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.30. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.30. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 57.22. Signal Matching rank-1 83.54
# K=8, Delta=114, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.91. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 76.12 mAP 56.23. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.17. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 57.06. Signal Matching rank-1 83.54
# K=8, Delta=115, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.88. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 75.62 mAP 56.15. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 57.02. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.95. Signal Matching rank-1 83.54
# K=8, Delta=116, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.83. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 75.62 mAP 56.09. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 56.98. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.87. Signal Matching rank-1 83.54
# K=8, Delta=117, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.78. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 75.12 mAP 55.87. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.12 mAP 56.92. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.82. Signal Matching rank-1 84.15
# K=8, Delta=118, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.74. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 75.12 mAP 55.77. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.12 mAP 56.84. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.75. Signal Matching rank-1 84.15
# K=8, Delta=119, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.70. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 75.12 mAP 55.72. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.12 mAP 56.66. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.55. Signal Matching rank-1 83.54
# K=8, Delta=120, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.62. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 74.63 mAP 55.56. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.12 mAP 56.45. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.34. Signal Matching rank-1 84.15
# K=8, Delta=121, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.57. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 74.63 mAP 55.48. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.62 mAP 56.35. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.24. Signal Matching rank-1 84.15
# K=8, Delta=122, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.54. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 74.63 mAP 55.39. Signal Matching rank-1 83.54
# Iteration 3: ReID rank-1 76.62 mAP 56.30. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.24. Signal Matching rank-1 84.76
# K=8, Delta=123, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.49. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 74.63 mAP 55.29. Signal Matching rank-1 82.93
# Iteration 3: ReID rank-1 76.62 mAP 56.10. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 56.03. Signal Matching rank-1 84.15
# K=8, Delta=124, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.45. Signal Matching rank-1 80.49
# Iteration 2: ReID rank-1 74.13 mAP 55.19. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 76.62 mAP 55.91. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 55.90. Signal Matching rank-1 84.15
# K=8, Delta=125, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.45. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 74.13 mAP 55.16. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.11 mAP 55.82. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 77.11 mAP 55.89. Signal Matching rank-1 84.15
# K=8, Delta=126, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.42. Signal Matching rank-1 81.10
# Iteration 2: ReID rank-1 74.63 mAP 55.13. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.11 mAP 55.72. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 77.11 mAP 55.70. Signal Matching rank-1 84.76
# K=8, Delta=127, Iteration=4
# Iteration 1: ReID rank-1 73.63 mAP 47.39. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 55.23. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.11 mAP 55.69. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 77.11 mAP 55.65. Signal Matching rank-1 84.76
# K=8, Delta=128, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.37. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 55.15. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.11 mAP 55.61. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 55.31. Signal Matching rank-1 84.76
# K=8, Delta=129, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.32. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 55.08. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.11 mAP 55.44. Signal Matching rank-1 82.32
# Iteration 4: ReID rank-1 76.62 mAP 55.07. Signal Matching rank-1 84.15
# K=8, Delta=130, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.29. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 55.01. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.36. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 55.06. Signal Matching rank-1 83.54
# K=8, Delta=131, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.26. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 54.96. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.25. Signal Matching rank-1 82.93
# Iteration 4: ReID rank-1 76.62 mAP 54.97. Signal Matching rank-1 83.54
# K=8, Delta=132, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.23. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 54.88. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.29. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 55.00. Signal Matching rank-1 84.15
# K=8, Delta=133, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.20. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 54.77. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.25. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 54.87. Signal Matching rank-1 84.15
# K=8, Delta=134, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.16. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 54.68. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.12. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 54.91. Signal Matching rank-1 84.15
# K=8, Delta=135, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.13. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 54.58. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 55.05. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 54.84. Signal Matching rank-1 84.15
# K=8, Delta=136, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.09. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 54.51. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 76.62 mAP 54.99. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 54.74. Signal Matching rank-1 84.15
# K=8, Delta=137, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.09. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.12 mAP 54.41. Signal Matching rank-1 81.10
# Iteration 3: ReID rank-1 77.11 mAP 54.88. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 76.62 mAP 54.63. Signal Matching rank-1 84.15
# K=8, Delta=138, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.05. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 54.36. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.61 mAP 54.88. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 76.62 mAP 54.67. Signal Matching rank-1 84.15
# K=8, Delta=139, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 47.00. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.12 mAP 54.26. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 77.61 mAP 54.79. Signal Matching rank-1 84.76
# Iteration 4: ReID rank-1 76.62 mAP 54.56. Signal Matching rank-1 84.15
# K=8, Delta=140, Iteration=4
# Iteration 1: ReID rank-1 74.13 mAP 46.98. Signal Matching rank-1 82.32
# Iteration 2: ReID rank-1 75.62 mAP 54.37. Signal Matching rank-1 81.71
# Iteration 3: ReID rank-1 78.11 mAP 54.90. Signal Matching rank-1 84.15
# Iteration 4: ReID rank-1 77.11 mAP 54.67. Signal Matching rank-1 84.15

# %%
plt.plot(list(range(140)), history_sigma['cmc_SM'], '-', color='blue', label='RCPM SM Rank-1')
plt.plot(list(range(140)), history_sigma['cmc_reid'], '--', color='blue', label='RCPM ReID Rank-1')
plt.plot(list(range(140)), history_sigma['mAP_reid'], '-.', color='blue', label='RCPM ReID mAP')

plt.legend()

# %% [markdown]
# ## Figure 5(c) with RCPM$^*$

# %%
import copy
from rcpm import update_module 
from rcpm import video_reid_performance
from rcpm import eval_tools
# import get_vision_record_dist, visual_affinity_update, trajectory_distance_update, norm_data

class Ablation2RecurrentContextPropagationModule(eval.RecurrentContextPropagationModule):

    def rcpm(self, distMat_new, gt_dist_new, iteration=1):
        print(distMat_new.max(), distMat_new.min())
        distMat_new = update_module.visual_affinity_update(
            # distMat_new,
            update_module.norm_data(distMat_new),
            gt_dist=gt_dist_new.copy(), 
            T=self.delta, 
            alpha=self.alpha
        )
        
        cmc_reid, mAP_reid = video_reid_performance.compute_video_cmc_map(
            distMat_new[self.query_index][:, self.gallery_index], 
            self.query_id, self.gallery_id,
            self.query_cam_id, 
            self.gallery_cam_id
        )
        gt_dist_new = update_module.trajectory_distance_update(
            distMat_new, 
            self.raw_gt_dist.copy(), 
            k=self.k
        )
        cmc_SM = eval_tools.get_signal_match_cmc(
            gt_dist_new[self.query_index].copy(), 
            self.gt_dist_is_inf[self.query_index].copy(),
            self.query_id.copy(), 
            self.traj_id.copy()
        )
        
        return distMat_new, gt_dist_new, cmc_reid, mAP_reid, cmc_SM
        
    def __call__(self, *args, **kwargs):
        print('K={}, Delta={}, Iteration={}'.format(self.k, self.delta, self.iters))
        cmc_reid, mAP_reid = video_reid_performance.compute_video_cmc_map(
            self.raw_distMat[self.query_index][:, self.gallery_index], 
            self.query_id, self.gallery_id,
            self.query_cam_id, 
            self.gallery_cam_id
        )
        cmc_SM = eval_tools.get_signal_match_cmc(
            self.raw_gt_dist[self.query_index].copy(), 
            self.gt_dist_is_inf[self.query_index].copy(),
            self.query_id.copy(), 
            self.traj_id.copy()
        )

        # print('Iteration {}: ReID rank-1 {:.2f} mAP {:.2f}. Signal Matching rank-1 {:.2f}'.format(
        #     0, cmc_reid[0] * 100, mAP_reid * 100, cmc_SM[0] * 100))

        last_distMat = self.raw_distMat
        last_gt_dist = self.raw_gt_dist
        history = {
            'cmc_reid': [],
            'mAP_reid': [],
            'cmc_SM': []
        }
        for i in range(self.iters):
            last_distMat, last_gt_dist, cmc_reid, mAP_reid, cmc_SM = self.rcpm(last_distMat, last_gt_dist, iteration=i+1)
            print('Iteration {}: ReID rank-1 {:.2f} mAP {:.2f}. Signal Matching rank-1 {:.2f}'.format(
                i + 1, cmc_reid[0] * 100, mAP_reid * 100, cmc_SM[0] * 100))
            history['cmc_reid'].append(cmc_reid[0] * 100)
            history['mAP_reid'].append(mAP_reid * 100)
            history['cmc_SM'].append(cmc_SM[0] * 100)

        return history


def ablation2_update_with_gps(distMat, all_info, query_index, gallery_index, bndbox_gps, trajectory, k=9, delta=74, iters=5):
    '''
    :param distMat: (g, g), the distance between gallery tracklet with gallery tracklet
    :param all_info: (num, 5), num is the total number of gallery tracklet, each row [p_id, cam_id, idx, idx+frame_num, frame_num]
    :param query_index: the query index for query tracklet in gallery tracklet
    :param gallery_index: the gallery index for query tracklet in gallery tracklet
    :param bndbox_gps: (image_num, 3), each raw: [time_id, gps_j, gps_w]
    :param trajectory: dict, the key is the corresponding person id. trajectory[p_id] : (n, 3), each row [timestamp, gps_j, gps_w]
    :return:
    '''
    gallery_info = all_info[gallery_index]
    gt_gps_dist, traj_id = eval.get_vision_record_dist(gallery_info.copy(), bndbox_gps.copy(), copy.deepcopy(trajectory))
    rcpm = Ablation2RecurrentContextPropagationModule(k=k, delta=delta, iters=iters, distMat=distMat, gt_dist=gt_gps_dist, traj_id=traj_id)
    rcpm.init_dataset_info(all_info=all_info, query_index=query_index, gallery_index=gallery_index)
    
    return rcpm()

# %%
k = 8
sigma = 74
max_iters = 9

distmat = utils.DataPacker.load(mmt_duke_dist_file)['g2g_distmat']
history_iters = ablation_update_with_gps(
    distmat, 
    wp_reid_dataset.test_info, 
    wp_reid_dataset.probe_index, 
    wp_reid_dataset.gallery_index,
    wp_reid_dataset.gps_info, 
    wp_reid_dataset.trajectory_info, 
    k=k,
    delta=sigma,
    iters=max_iters
)

history2_iters = ablation2_update_with_gps(
    distmat, 
    wp_reid_dataset.test_info, 
    wp_reid_dataset.probe_index, 
    wp_reid_dataset.gallery_index,
    wp_reid_dataset.gps_info, 
    wp_reid_dataset.trajectory_info, 
    k=k,
    delta=sigma,
    iters=max_iters
)
# Out:
# Load data <--- /Users/jangsoopark/Documents/course/2023/fall/internet-of-things/WP-ReID/_test/files/mmt_duke_g2g_distmat.json
# K=8, Delta=74, Iteration=9
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# Iteration 2: ReID rank-1 75.62 mAP 59.09. Signal Matching rank-1 84.15
# Iteration 3: ReID rank-1 76.12 mAP 60.87. Signal Matching rank-1 86.59
# Iteration 4: ReID rank-1 77.61 mAP 61.47. Signal Matching rank-1 84.76
# Iteration 5: ReID rank-1 77.11 mAP 61.02. Signal Matching rank-1 86.59
# Iteration 6: ReID rank-1 78.11 mAP 61.41. Signal Matching rank-1 86.59
# Iteration 7: ReID rank-1 77.11 mAP 61.30. Signal Matching rank-1 86.59
# Iteration 8: ReID rank-1 76.62 mAP 61.40. Signal Matching rank-1 86.59
# Iteration 9: ReID rank-1 77.11 mAP 61.14. Signal Matching rank-1 86.59
# K=8, Delta=74, Iteration=9
# 1.0 0.0
# Iteration 1: ReID rank-1 73.13 mAP 49.14. Signal Matching rank-1 81.71
# 1.0 0.0
# Iteration 2: ReID rank-1 72.64 mAP 59.62. Signal Matching rank-1 84.15
# 1.0 0.0
# Iteration 3: ReID rank-1 69.65 mAP 59.95. Signal Matching rank-1 84.15
# 1.0 0.0
# Iteration 4: ReID rank-1 71.14 mAP 59.80. Signal Matching rank-1 82.93
# 1.0 0.0
# Iteration 5: ReID rank-1 67.16 mAP 57.36. Signal Matching rank-1 83.54
# 1.0 0.0
# Iteration 6: ReID rank-1 62.69 mAP 54.92. Signal Matching rank-1 83.54
# 1.0 0.0
# Iteration 7: ReID rank-1 60.20 mAP 52.50. Signal Matching rank-1 83.54
# 1.0 0.0
# Iteration 8: ReID rank-1 57.21 mAP 51.52. Signal Matching rank-1 82.93
# 1.0 0.0
# Iteration 9: ReID rank-1 49.25 mAP 49.04. Signal Matching rank-1 82.32

# %%
plt.plot(list(range(max_iters)), history_iters['cmc_SM'], '-p', color='blue', label='RCPM SM Rank-1')
plt.plot(list(range(max_iters)), history_iters['cmc_reid'], '--p', color='blue', label='RCPM ReID Rank-1')
plt.plot(list(range(max_iters)), history_iters['mAP_reid'], '-.p', color='blue', label='RCPM ReID mAP')

plt.plot(list(range(max_iters)), history2_iters['cmc_SM'], '-p', color='red', label='RCPM$^*$ SM Rank-1')
plt.plot(list(range(max_iters)), history2_iters['cmc_reid'], '--p', color='red', label='RCPM$^*$ ReID Rank-1')
plt.plot(list(range(max_iters)), history2_iters['mAP_reid'], '-.p', color='red', label='RCPM$^*$ ReID mAP')

plt.legend()

# %% [markdown]
# ## Figure 5

# %%
fig, axes = plt.subplots(1, 3, figsize=(32, 8))

# Figure 5 (a)
axes[0].plot(list(range(19)), history_k['cmc_SM'], '-', color='blue', label='RCPM SM Rank-1')
axes[0].plot(list(range(19)), history_k['cmc_reid'], '--', color='blue', label='RCPM ReID Rank-1')
axes[0].plot(list(range(19)), history_k['mAP_reid'], '-.', color='blue', label='RCPM ReID mAP')

axes[0].set_ylabel('Performance(%)')
axes[0].set_xlabel('K')
axes[0].legend()

# Figure 5 (b)
axes[1].plot(list(range(140)), history_sigma['cmc_SM'], '-', color='blue', label='RCPM SM Rank-1')
axes[1].plot(list(range(140)), history_sigma['cmc_reid'], '--', color='blue', label='RCPM ReID Rank-1')
axes[1].plot(list(range(140)), history_sigma['mAP_reid'], '-.', color='blue', label='RCPM ReID mAP')

axes[1].set_ylabel('Performance(%)')
axes[1].set_xlabel('$\sigma$')
axes[1].legend()

# Figure 5 (c) - RCPM
axes[2].plot(list(range(9)), history_iters['cmc_SM'], '-p', color='blue', label='RCPM SM Rank-1')
axes[2].plot(list(range(9)), history_iters['cmc_reid'], '--p', color='blue', label='RCPM ReID Rank-1')
axes[2].plot(list(range(9)), history_iters['mAP_reid'], '-.p', color='blue', label='RCPM ReID mAP')

# Figure 5 (c) - RCPM*
axes[2].plot(list(range(9)), history2_iters['cmc_SM'], '-p', color='red', label='RCPM$^*$ SM Rank-1')
axes[2].plot(list(range(9)), history2_iters['cmc_reid'], '--p', color='red', label='RCPM$^*$ ReID Rank-1')
axes[2].plot(list(range(9)), history2_iters['mAP_reid'], '-.p', color='red', label='RCPM$^*$ ReID mAP')

axes[2].set_ylabel('Performance(%)')
axes[2].set_xlabel('Iterations')
axes[2].legend()
